# %%
# !unzip vbdi-ml-6-main.zip
# Out:
# Archive:  vbdi-ml-6-main.zip
# 26837ee7c348eb1b9aa881d0d542d5e3af0fa4cd
#    creating: vbdi-ml-6-main/
#   inflating: vbdi-ml-6-main/LICENSE
#   inflating: vbdi-ml-6-main/README.md
#   inflating: vbdi-ml-6-main/ReceiptOCR.ipynb
#   inflating: vbdi-ml-6-main/alignment.py
#   inflating: vbdi-ml-6-main/config_vietocr.yml
#   inflating: vbdi-ml-6-main/detection.py
#   inflating: vbdi-ml-6-main/main.py
#    creating: vbdi-ml-6-main/network/
#   inflating: vbdi-ml-6-main/network/__init__.py
#   inflating: vbdi-ml-6-main/network/_deeplab.py
#    creating: vbdi-ml-6-main/network/backbone/
#   inflating: vbdi-ml-6-main/network/backbone/__init__.py
#   inflating: vbdi-ml-6-main/network/backbone/hrnetv2.py
#   inflating: vbdi-ml-6-main/network/backbone/mobilenetv2.py
#   inflating: vbdi-ml-6-main/network/backbone/resnet.py
#   inflating: vbdi-ml-6-main/network/backbone/xception.py
#   inflating: vbdi-ml-6-main/network/modeling.py
#   inflating: vbdi-ml-6-main/network/utils.py
# ...

# %%
# %cd vbdi-ml-6-main/weights
# !pip install --upgrade gdown
# !gdown 1Q4y-USFFtNaOQdaOu4mIrd68RUmBMk58
# !gdown 148YIwF3ykDUL5-CAIlVoKLndBzD9U6Cd
# %cd ..
# !gdown 1A0BwSb6abgElVqV2yR3No4OIZEIzY6jX
# !unzip mcocr_public_train_test_shared_data.zip
# Out:
# /content/vbdi-ml-6-main/weights
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1Q4y-USFFtNaOQdaOu4mIrd68RUmBMk58
# From (redirected): https://drive.google.com/uc?id=1Q4y-USFFtNaOQdaOu4mIrd68RUmBMk58&confirm=t&uuid=eb8e537a-78f2-400d-a2af-790385673691
# To: /content/vbdi-ml-6-main/weights/transformerocr.pth
# 100% 152M/152M [00:03<00:00, 47.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=148YIwF3ykDUL5-CAIlVoKLndBzD9U6Cd
# From (redirected): https://drive.google.com/uc?id=148YIwF3ykDUL5-CAIlVoKLndBzD9U6Cd&confirm=t&uuid=b6bfcde7-526f-4ebb-82c7-4c4f1c4748b8
# To: /content/vbdi-ml-6-main/weights/best_angle_classification_cnn_v2.pt
# 100% 157M/157M [00:09<00:00, 16.6MB/s]
# /content/vbdi-ml-6-main
# Downloading...
# ...

# %%
# !pip install -qr requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.7/876.7 kB 39.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 86.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 68.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.5 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
Image.open('mcocr_public_train_test_shared_data/mcocr_val_data/val_images/mcocr_val_145115mxpds.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280>

# %%
# !python main.py --image_path mcocr_public_train_test_shared_data/mcocr_val_data/val_images/mcocr_val_145115mxpds.jpg
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100% 13.6M/13.6M [00:00<00:00, 260MB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to /root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer/en_PP-OCRv3_det_infer.tar
# 100% 4.00M/4.00M [00:17<00:00, 231kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to /root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer/en_PP-OCRv4_rec_infer.tar
# 100% 10.2M/10.2M [00:11<00:00, 862kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to /root/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer/ch_ppocr_mobile_v2.0_cls_infer.tar
# 100% 2.19M/2.19M [00:07<00:00, 312kiB/s]
# VM + QNH 86 Trần Phú: ADDRESS
# Số 86 Đường Trần Phú, P. Cẩm Tây: ADDRESS
# VinCommerce: SELLER
# TP Cẩm Phả, T.Quảng Ninh: ADDRESS
# ...
